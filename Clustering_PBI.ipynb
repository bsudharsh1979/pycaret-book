# %% [markdown]
# <a href="https://colab.research.google.com/github/bsudharsh1979/pycaret-book/blob/main/Clustering_PBI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
from pycaret.clustering import *
import pandas as pd

# %%
data = pd.read_csv('clustering.csv')

# %%
data.head()
# Out:
#                 Country    2000    2001    2002    2003    2004    2005  \
# 0           Afghanistan  0.0926  0.0940  0.0944  0.0894  0.0981  0.0995
# 1                Angola  0.0191  0.0448  0.0333  0.0355  0.0397  0.0285
# 2               Andorra  0.0935  0.0936  0.0912  0.0846  0.0821  0.0857
# 3  United Arab Emirates  0.0237  0.0248  0.0272  0.0265  0.0246  0.0232
# 4             Argentina  0.0847  0.0862  0.0765  0.0711  0.0723  0.0761
#
#      2006    2007    2008    2009    2010    2011    2012    2013    2014  \
# 0  0.1062  0.0990  0.1026  0.0982  0.0857  0.0856  0.0790  0.0881  0.0953
# 1  0.0269  0.0297  0.0332  0.0384  0.0270  0.0265  0.0240  0.0273  0.0243
# 2  0.0843  0.0843  0.0879  0.0903  0.0945  0.0977  0.1005  0.1011  0.1028
# 3  0.0233  0.0257  0.0293  0.0405  0.0388  0.0367  0.0343  0.0359  0.0363
# 4  0.0755  0.0761  0.0767  0.0901  0.0861  0.0840  0.0846  0.0837  0.0826
#
#      2015    2016    2017
# 0  0.1011  0.1096  0.1178
# 1  0.0261  0.0271  0.0279
# ...

# %%
#check the shape of data
data.shape
# Out:
# (190, 19)

# %%
from pycaret.clustering import *

exp_clu101 = setup(data, normalize = True,
                   ignore_features = ['Country'],
                   session_id = 123)
# Out:
# <style type="text/css">
# #T_75459_row5_col1, #T_75459_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_75459" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75459_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_75459_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75459_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75459_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_75459_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_75459_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75459_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_75459_row1_col1" class="data row1 col1" >(190, 19)</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Tipos de modelos de clsutering

# %% [markdown]
# ![clustering.png](attachment:clustering.png)

# %%
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
# kmodes                   K-Modes Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# ...

# %% [markdown]
# ##### Partitional Clustering

# %%
kmeans = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_80e3c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80e3c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_80e3c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_80e3c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_80e3c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_80e3c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_80e3c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80e3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80e3c_row0_col0" class="data row0 col0" >0.3904</td>
#       <td id="T_80e3c_row0_col1" class="data row0 col1" >224.9803</td>
# ...

# %%
# !pip install kmodes

# %%
kmodes = create_model('kmodes', num_clusters = 5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c70c9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c70c9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c70c9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c70c9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c70c9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c70c9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c70c9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c70c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c70c9_row0_col0" class="data row0 col0" >-0.4182</td>
#       <td id="T_c70c9_row0_col1" class="data row0 col1" >1.8524</td>
# ...

# %% [markdown]
# ##### Hierarchical Clustering

# %%
birch = create_model('birch')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9da48" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9da48_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9da48_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9da48_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9da48_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9da48_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9da48_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9da48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9da48_row0_col0" class="data row0 col0" >0.4503</td>
#       <td id="T_9da48_row0_col1" class="data row0 col1" >178.8133</td>
# ...

# %%
hclust = create_model('hclust')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8fb7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8fb7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d8fb7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d8fb7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d8fb7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d8fb7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d8fb7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8fb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8fb7_row0_col0" class="data row0 col0" >0.4180</td>
#       <td id="T_d8fb7_row0_col1" class="data row0 col1" >195.1514</td>
# ...

# %% [markdown]
# ##### Density based

# %%
meanshift = create_model('meanshift')
# Out:
# <style type="text/css">
# </style>
# <table id="T_65cfd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65cfd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_65cfd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_65cfd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_65cfd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_65cfd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_65cfd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65cfd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65cfd_row0_col0" class="data row0 col0" >0.4540</td>
#       <td id="T_65cfd_row0_col1" class="data row0 col1" >93.1824</td>
# ...

# %%
sc = create_model('sc')
# Out:
# <style type="text/css">
# </style>
# <table id="T_09dfc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09dfc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_09dfc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_09dfc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_09dfc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_09dfc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_09dfc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09dfc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09dfc_row0_col0" class="data row0 col0" >0.4838</td>
#       <td id="T_09dfc_row0_col1" class="data row0 col1" >112.7495</td>
# ...

# %%
optics = create_model('optics')
# Out:
# <style type="text/css">
# </style>
# <table id="T_000bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_000bd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_000bd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_000bd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_000bd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_000bd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_000bd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_000bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_000bd_row0_col0" class="data row0 col0" >-0.3109</td>
#       <td id="T_000bd_row0_col1" class="data row0 col1" >9.5349</td>
# ...

# %%
sc_results = assign_model(sc)
sc_results.head()
# Out:
#      2000    2001    2002    2003    2004    2005    2006    2007    2008  \
# 0  0.0926  0.0940  0.0944  0.0894  0.0981  0.0995  0.1062  0.0990  0.1026
# 1  0.0191  0.0448  0.0333  0.0355  0.0397  0.0285  0.0269  0.0297  0.0332
# 2  0.0935  0.0936  0.0912  0.0846  0.0821  0.0857  0.0843  0.0843  0.0879
# 3  0.0237  0.0248  0.0272  0.0265  0.0246  0.0232  0.0233  0.0257  0.0293
# 4  0.0847  0.0862  0.0765  0.0711  0.0723  0.0761  0.0755  0.0761  0.0767
#
#      2009    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0  0.0982  0.0857  0.0856  0.0790  0.0881  0.0953  0.1011  0.1096  0.1178
# 1  0.0384  0.0270  0.0265  0.0240  0.0273  0.0243  0.0261  0.0271  0.0279
# 2  0.0903  0.0945  0.0977  0.1005  0.1011  0.1028  0.1025  0.1032  0.1032
# 3  0.0405  0.0388  0.0367  0.0343  0.0359  0.0363  0.0358  0.0340  0.0333
# 4  0.0901  0.0861  0.0840  0.0846  0.0837  0.0826  0.0879  0.0754  0.0912
#
#      Cluster
# 0  Cluster 3
# 1  Cluster 0
# 2  Cluster 3
# 3  Cluster 0
# ...

# %%
sc_results.to_excel("outlier_records.xlsx")

# %%
plot_model(sc)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(sc, plot = 'elbow')

# %%
plot_model(sc, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
save_model(kmeans,'C:/Users/leire/Desktop/automl/clustering')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-bb1001d8a874> in <cell line: 1>()
# ----> 1 save_model(kmeans,'C:/Users/leire/Desktop/automl/clustering')
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/clustering/functional.py in save_model(model, model_name, model_only, verbose, **kwargs)
#    1003     """
#    1004
# -> 1005     return _CURRENT_EXPERIMENT.save_model(
#    1006         model=model,
#    1007         model_name=model_name,
#
# ...
